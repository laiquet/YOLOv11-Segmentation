# %%
from pathlib import Path
import os
import sys

# %%
Root = os.getcwd()

# %%
Root
# Out:
# 'c:\\Users\\tala\\Downloads\\Collab Presentation Material\\To_be_Tested\\YOLO'

# %%
print(Path(Root))
# Out:
# c:\Users\tala\Downloads\Collab Presentation Material\To_be_Tested\YOLO

# %%
from PIL import Image
img = Image.open('337215_April_edit.jpg')
img = img.resize((1080,350))
img.save('337215_April_edit1.jpg')
